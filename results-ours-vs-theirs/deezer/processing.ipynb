# %%
import os
from collections import defaultdict
import re

# %%
def load_txt_files(directory):
    # load all txt files in a directory
    data = defaultdict(list)
    for filename in os.listdir(directory):
        if filename.endswith(".txt"):
            with open(os.path.join(directory, filename), 'r') as file:
                data[filename] = file.read()
    return data

data = load_txt_files('.')

# %%
data
# Out:
# defaultdict(list,
#             {'results_deezer_0.txt': 'K 20 T 10 alpha_word 0.2 alpha_ent 0.30: \n51.4062\n\n\nK 20 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.4062\n\n\nK 20 T 10 alpha_word 0.4 alpha_ent 0.30: \n50.824000000000005\n\n\nK 20 T 10 alpha_word 0.5 alpha_ent 0.30: \n50.1422\n\n\nK 20 T 10 alpha_word 0.2 alpha_ent 0.40: \n59.6488\n\n\nK 20 T 10 alpha_word 0.3 alpha_ent 0.40: \n59.6488\n\n\nK 20 T 10 alpha_word 0.4 alpha_ent 0.40: \n59.42040000000001\n\n\nK 20 T 10 alpha_word 0.5 alpha_ent 0.40: \n59.0009\n\n\nK 50 T 10 alpha_word 0.2 alpha_ent 0.30: \n51.9509\n\n\nK 50 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.5633\n\n\nK 50 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.477300000000014\n\n\nK 50 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 50 T 10 alpha_word 0.2 alpha_ent 0.40: \n57.787600000000005\n\n\nK 50 T 10 alpha_word 0.3 alpha_ent 0.40: \n57.6685\n\n\nK 50 T 10 alpha_word 0.4 alpha_ent 0.40: \n56.3269\n\n\nK 50 T 10 alpha_word 0.5 alpha_ent 0.40: \n58.888\n\n\nK 100 T 10 alpha_word 0.2 alpha_ent 0.30: \n50.08730000000001\n\n\nK 100 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.9088\n\n\nK 100 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.4439\n\n\nK 100 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 100 T 10 alpha_word 0.2 alpha_ent 0.40: \n52.974700000000006\n\n\nK 100 T 10 alpha_word 0.3 alpha_ent 0.40: \n53.2859\n\n\nK 100 T 10 alpha_word 0.4 alpha_ent 0.40: \n53.0769\n\n\nK 100 T 10 alpha_word 0.5 alpha_ent 0.40: \n57.2764\n\n\nK 200 T 10 alpha_word 0.2 alpha_ent 0.30: \n49.0811\n\n\nK 200 T 10 alpha_word 0.3 alpha_ent 0.30: \n52.394\n\n\nK 200 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.32730000000001\n\n\nK 200 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 200 T 10 alpha_word 0.2 alpha_ent 0.40: \n55.3034\n\n\nK 200 T 10 alpha_word 0.3 alpha_ent 0.40: \n54.34559999999999\n\n\nK 200 T 10 alpha_word 0.4 alpha_ent 0.40: \n54.2801\n\n\nK 200 T 10 alpha_word 0.5 alpha_ent 0.40: \n59.0812\n\n\n',
#              'results_deezer_1.txt': 'K 20 T 10 alpha_word 0.2 alpha_ent 0.30: \n51.4062\n\n\nK 20 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.4062\n\n\nK 20 T 10 alpha_word 0.4 alpha_ent 0.30: \n50.824000000000005\n\n\nK 20 T 10 alpha_word 0.5 alpha_ent 0.30: \n50.1422\n\n\nK 20 T 10 alpha_word 0.2 alpha_ent 0.40: \n54.8392\n\n\nK 20 T 10 alpha_word 0.3 alpha_ent 0.40: \n54.8392\n\n\nK 20 T 10 alpha_word 0.4 alpha_ent 0.40: \n54.610800000000005\n\n\nK 20 T 10 alpha_word 0.5 alpha_ent 0.40: \n54.19130000000001\n\n\nK 50 T 10 alpha_word 0.2 alpha_ent 0.30: \n51.9509\n\n\nK 50 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.5633\n\n\nK 50 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.477300000000014\n\n\nK 50 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 50 T 10 alpha_word 0.2 alpha_ent 0.40: \n57.258700000000005\n\n\nK 50 T 10 alpha_word 0.3 alpha_ent 0.40: \n57.1396\n\n\nK 50 T 10 alpha_word 0.4 alpha_ent 0.40: \n56.1506\n\n\nK 50 T 10 alpha_word 0.5 alpha_ent 0.40: \n58.3591\n\n\nK 100 T 10 alpha_word 0.2 alpha_ent 0.30: \n50.08730000000001\n\n\nK 100 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.9088\n\n\nK 100 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.4439\n\n\nK 100 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 100 T 10 alpha_word 0.2 alpha_ent 0.40: \n51.6697\n\n\nK 100 T 10 alpha_word 0.3 alpha_ent 0.40: \n52.5029\n\n\nK 100 T 10 alpha_word 0.4 alpha_ent 0.40: \n52.5549\n\n\nK 100 T 10 alpha_word 0.5 alpha_ent 0.40: \n56.49339999999998\n\n\nK 200 T 10 alpha_word 0.2 alpha_ent 0.30: \n49.0811\n\n\nK 200 T 10 alpha_word 0.3 alpha_ent 0.30: \n52.394\n\n\nK 200 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.32730000000001\n\n\nK 200 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 200 T 10 alpha_word 0.2 alpha_ent 0.40: \n53.36890000000001\n\n\nK 200 T 10 alpha_word 0.3 alpha_ent 0.40: \n53.1849\n\n\nK 200 T 10 alpha_word 0.4 alpha_ent 0.40: \n53.506299999999996\n\n\nK 200 T 10 alpha_word 0.5 alpha_ent 0.40: \n57.9205\n\n\nK 20 T 10 alpha_word 0.2 alpha_ent 0.30: \n51.4062\n\n\nK 20 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.4062\n\n\nK 20 T 10 alpha_word 0.4 alpha_ent 0.30: \n50.824000000000005\n\n\nK 20 T 10 alpha_word 0.5 alpha_ent 0.30: \n50.1422\n\n\nK 20 T 10 alpha_word 0.2 alpha_ent 0.40: \n54.5056\n\n\nK 20 T 10 alpha_word 0.3 alpha_ent 0.40: \n54.5056\n\n\nK 20 T 10 alpha_word 0.4 alpha_ent 0.40: \n54.2772\n\n\nK 20 T 10 alpha_word 0.5 alpha_ent 0.40: \n53.85770000000001\n\n\nK 50 T 10 alpha_word 0.2 alpha_ent 0.30: \n51.9509\n\n\nK 50 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.5633\n\n\nK 50 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.477300000000014\n\n\nK 50 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 50 T 10 alpha_word 0.2 alpha_ent 0.40: \n52.856800000000014\n\n\nK 50 T 10 alpha_word 0.3 alpha_ent 0.40: \n52.73770000000001\n\n\nK 50 T 10 alpha_word 0.4 alpha_ent 0.40: \n54.6833\n\n\nK 50 T 10 alpha_word 0.5 alpha_ent 0.40: \n53.95720000000001\n\n\nK 100 T 10 alpha_word 0.2 alpha_ent 0.30: \n50.08730000000001\n\n\nK 100 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.9088\n\n\nK 100 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.4439\n\n\nK 100 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 100 T 10 alpha_word 0.2 alpha_ent 0.40: \n45.0547\n\n\nK 100 T 10 alpha_word 0.3 alpha_ent 0.40: \n48.5339\n\n\nK 100 T 10 alpha_word 0.4 alpha_ent 0.40: \n49.908899999999996\n\n\nK 100 T 10 alpha_word 0.5 alpha_ent 0.40: \n52.52440000000001\n\n\nK 200 T 10 alpha_word 0.2 alpha_ent 0.30: \n49.0811\n\n\nK 200 T 10 alpha_word 0.3 alpha_ent 0.30: \n52.394\n\n\nK 200 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.32730000000001\n\n\nK 200 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 200 T 10 alpha_word 0.2 alpha_ent 0.40: \n49.83040000000001\n\n\nK 200 T 10 alpha_word 0.3 alpha_ent 0.40: \n51.061800000000005\n\n\nK 200 T 10 alpha_word 0.4 alpha_ent 0.40: \n52.0909\n\n\nK 200 T 10 alpha_word 0.5 alpha_ent 0.40: \n55.797399999999996\n\n\n',
#              'results_deezer_10.txt': 'K 20 T 10 alpha_word 0.2 alpha_ent 0.30: \n51.4062\n\n\nK 20 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.4062\n\n\nK 20 T 10 alpha_word 0.4 alpha_ent 0.30: \n50.824000000000005\n\n\nK 20 T 10 alpha_word 0.5 alpha_ent 0.30: \n50.1422\n\n\nK 20 T 10 alpha_word 0.2 alpha_ent 0.40: \n54.211999999999996\n\n\nK 20 T 10 alpha_word 0.3 alpha_ent 0.40: \n54.211999999999996\n\n\nK 20 T 10 alpha_word 0.4 alpha_ent 0.40: \n53.983599999999996\n\n\nK 20 T 10 alpha_word 0.5 alpha_ent 0.40: \n53.5641\n\n\nK 50 T 10 alpha_word 0.2 alpha_ent 0.30: \n51.9509\n\n\nK 50 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.5633\n\n\nK 50 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.477300000000014\n\n\nK 50 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 50 T 10 alpha_word 0.2 alpha_ent 0.40: \n58.00090000000001\n\n\nK 50 T 10 alpha_word 0.3 alpha_ent 0.40: \n57.881800000000005\n\n\nK 50 T 10 alpha_word 0.4 alpha_ent 0.40: \n56.398\n\n\nK 50 T 10 alpha_word 0.5 alpha_ent 0.40: \n59.10129999999999\n\n\nK 100 T 10 alpha_word 0.2 alpha_ent 0.30: \n49.95269999999999\n\n\nK 100 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.9088\n\n\nK 100 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.4439\n\n\nK 100 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 100 T 10 alpha_word 0.2 alpha_ent 0.40: \n54.3262\n\n\nK 100 T 10 alpha_word 0.3 alpha_ent 0.40: \n54.09680000000001\n\n\nK 100 T 10 alpha_word 0.4 alpha_ent 0.40: \n53.61749999999999\n\n\nK 100 T 10 alpha_word 0.5 alpha_ent 0.40: \n58.087300000000006\n\n\nK 200 T 10 alpha_word 0.2 alpha_ent 0.30: \n49.0811\n\n\nK 200 T 10 alpha_word 0.3 alpha_ent 0.30: \n52.394\n\n\nK 200 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.32730000000001\n\n\nK 200 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 200 T 10 alpha_word 0.2 alpha_ent 0.40: \n48.77140000000001\n\n\nK 200 T 10 alpha_word 0.3 alpha_ent 0.40: \n50.4264\n\n\nK 200 T 10 alpha_word 0.4 alpha_ent 0.40: \n51.667300000000004\n\n\nK 200 T 10 alpha_word 0.5 alpha_ent 0.40: \n55.16200000000001\n\n\n',
#              'results_deezer_2.txt': 'K 20 T 10 alpha_word 0.2 alpha_ent 0.30: \n51.4062\n\n\nK 20 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.4062\n\n\nK 20 T 10 alpha_word 0.4 alpha_ent 0.30: \n50.824000000000005\n\n\nK 20 T 10 alpha_word 0.5 alpha_ent 0.30: \n50.1422\n\n\nK 20 T 10 alpha_word 0.2 alpha_ent 0.40: \n57.147800000000004\n\n\nK 20 T 10 alpha_word 0.3 alpha_ent 0.40: \n57.147800000000004\n\n\nK 20 T 10 alpha_word 0.4 alpha_ent 0.40: \n56.91940000000001\n\n\nK 20 T 10 alpha_word 0.5 alpha_ent 0.40: \n56.499900000000004\n\n\nK 50 T 10 alpha_word 0.2 alpha_ent 0.30: \n51.9509\n\n\nK 50 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.5633\n\n\nK 50 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.477300000000014\n\n\nK 50 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 50 T 10 alpha_word 0.2 alpha_ent 0.40: \n52.607200000000006\n\n\nK 50 T 10 alpha_word 0.3 alpha_ent 0.40: \n52.4881\n\n\nK 50 T 10 alpha_word 0.4 alpha_ent 0.40: \n54.600100000000005\n\n\nK 50 T 10 alpha_word 0.5 alpha_ent 0.40: \n53.707599999999985\n\n\nK 100 T 10 alpha_word 0.2 alpha_ent 0.30: \n50.112800000000014\n\n\nK 100 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.9088\n\n\nK 100 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.4439\n\n\nK 100 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 100 T 10 alpha_word 0.2 alpha_ent 0.40: \n53.15019999999999\n\n\nK 100 T 10 alpha_word 0.3 alpha_ent 0.40: \n53.3912\n\n\nK 100 T 10 alpha_word 0.4 alpha_ent 0.40: \n53.1471\n\n\nK 100 T 10 alpha_word 0.5 alpha_ent 0.40: \n57.38169999999999\n\n\nK 200 T 10 alpha_word 0.2 alpha_ent 0.30: \n49.0811\n\n\nK 200 T 10 alpha_word 0.3 alpha_ent 0.30: \n52.394\n\n\nK 200 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.32730000000001\n\n\nK 200 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 200 T 10 alpha_word 0.2 alpha_ent 0.40: \n46.7294\n\n\nK 200 T 10 alpha_word 0.3 alpha_ent 0.40: \n49.20120000000001\n\n\nK 200 T 10 alpha_word 0.4 alpha_ent 0.40: \n50.8505\n\n\nK 200 T 10 alpha_word 0.5 alpha_ent 0.40: \n53.9368\n\n\n',
#              'results_deezer_3.txt': 'K 20 T 10 alpha_word 0.2 alpha_ent 0.30: \n51.4062\n\n\nK 20 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.4062\n\n\nK 20 T 10 alpha_word 0.4 alpha_ent 0.30: \n50.824000000000005\n\n\nK 20 T 10 alpha_word 0.5 alpha_ent 0.30: \n50.1422\n\n\nK 20 T 10 alpha_word 0.2 alpha_ent 0.40: \n55.91359999999999\n\n\nK 20 T 10 alpha_word 0.3 alpha_ent 0.40: \n55.91359999999999\n\n\nK 20 T 10 alpha_word 0.4 alpha_ent 0.40: \n55.68519999999999\n\n\nK 20 T 10 alpha_word 0.5 alpha_ent 0.40: \n55.265699999999995\n\n\nK 50 T 10 alpha_word 0.2 alpha_ent 0.30: \n51.9509\n\n\nK 50 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.5633\n\n\nK 50 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.477300000000014\n\n\nK 50 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 50 T 10 alpha_word 0.2 alpha_ent 0.40: \n54.8254\n\n\nK 50 T 10 alpha_word 0.3 alpha_ent 0.40: \n54.706300000000006\n\n\nK 50 T 10 alpha_word 0.4 alpha_ent 0.40: \n55.339499999999994\n\n\nK 50 T 10 alpha_word 0.5 alpha_ent 0.40: \n55.9258\n\n\nK 100 T 10 alpha_word 0.2 alpha_ent 0.30: \n50.20020000000001\n\n\nK 100 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.9088\n\n\nK 100 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.4439\n\n\nK 100 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 100 T 10 alpha_word 0.2 alpha_ent 0.40: \n54.46769999999999\n\n\nK 100 T 10 alpha_word 0.3 alpha_ent 0.40: \n54.181699999999985\n\n\nK 100 T 10 alpha_word 0.4 alpha_ent 0.40: \n53.67409999999999\n\n\nK 100 T 10 alpha_word 0.5 alpha_ent 0.40: \n58.17219999999998\n\n\nK 200 T 10 alpha_word 0.2 alpha_ent 0.30: \n49.0811\n\n\nK 200 T 10 alpha_word 0.3 alpha_ent 0.30: \n52.394\n\n\nK 200 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.32730000000001\n\n\nK 200 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 200 T 10 alpha_word 0.2 alpha_ent 0.40: \n46.3959\n\n\nK 200 T 10 alpha_word 0.3 alpha_ent 0.40: \n49.001099999999994\n\n\nK 200 T 10 alpha_word 0.4 alpha_ent 0.40: \n50.717099999999995\n\n\nK 200 T 10 alpha_word 0.5 alpha_ent 0.40: \n53.73669999999999\n\n\n',
#              'results_deezer_4.txt': 'K 20 T 10 alpha_word 0.2 alpha_ent 0.30: \n51.4062\n\n\nK 20 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.4062\n\n\nK 20 T 10 alpha_word 0.4 alpha_ent 0.30: \n50.824000000000005\n\n\nK 20 T 10 alpha_word 0.5 alpha_ent 0.30: \n50.1422\n\n\nK 20 T 10 alpha_word 0.2 alpha_ent 0.40: \n54.46379999999999\n\n\nK 20 T 10 alpha_word 0.3 alpha_ent 0.40: \n54.46379999999999\n\n\nK 20 T 10 alpha_word 0.4 alpha_ent 0.40: \n54.23540000000001\n\n\nK 20 T 10 alpha_word 0.5 alpha_ent 0.40: \n53.815900000000006\n\n\nK 50 T 10 alpha_word 0.2 alpha_ent 0.30: \n51.9509\n\n\nK 50 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.5633\n\n\nK 50 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.477300000000014\n\n\nK 50 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 50 T 10 alpha_word 0.2 alpha_ent 0.40: \n57.04900000000001\n\n\nK 50 T 10 alpha_word 0.3 alpha_ent 0.40: \n56.9299\n\n\nK 50 T 10 alpha_word 0.4 alpha_ent 0.40: \n56.08069999999999\n\n\nK 50 T 10 alpha_word 0.5 alpha_ent 0.40: \n58.14939999999999\n\n\nK 100 T 10 alpha_word 0.2 alpha_ent 0.30: \n50.1803\n\n\nK 100 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.9088\n\n\nK 100 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.4439\n\n\nK 100 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 100 T 10 alpha_word 0.2 alpha_ent 0.40: \n50.636199999999995\n\n\nK 100 T 10 alpha_word 0.3 alpha_ent 0.40: \n51.882799999999996\n\n\nK 100 T 10 alpha_word 0.4 alpha_ent 0.40: \n52.14149999999999\n\n\nK 100 T 10 alpha_word 0.5 alpha_ent 0.40: \n55.87329999999999\n\n\nK 200 T 10 alpha_word 0.2 alpha_ent 0.30: \n49.0811\n\n\nK 200 T 10 alpha_word 0.3 alpha_ent 0.30: \n52.394\n\n\nK 200 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.32730000000001\n\n\nK 200 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 200 T 10 alpha_word 0.2 alpha_ent 0.40: \n46.8879\n\n\nK 200 T 10 alpha_word 0.3 alpha_ent 0.40: \n49.296299999999995\n\n\nK 200 T 10 alpha_word 0.4 alpha_ent 0.40: \n50.9139\n\n\nK 200 T 10 alpha_word 0.5 alpha_ent 0.40: \n54.0319\n\n\n',
#              'results_deezer_5.txt': 'K 20 T 10 alpha_word 0.2 alpha_ent 0.30: \n51.4062\n\n\nK 20 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.4062\n\n\nK 20 T 10 alpha_word 0.4 alpha_ent 0.30: \n50.824000000000005\n\n\nK 20 T 10 alpha_word 0.5 alpha_ent 0.30: \n50.1422\n\n\nK 20 T 10 alpha_word 0.2 alpha_ent 0.40: \n57.48019999999999\n\n\nK 20 T 10 alpha_word 0.3 alpha_ent 0.40: \n57.48019999999999\n\n\nK 20 T 10 alpha_word 0.4 alpha_ent 0.40: \n57.251799999999996\n\n\nK 20 T 10 alpha_word 0.5 alpha_ent 0.40: \n56.832300000000004\n\n\nK 50 T 10 alpha_word 0.2 alpha_ent 0.30: \n51.9509\n\n\nK 50 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.5633\n\n\nK 50 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.477300000000014\n\n\nK 50 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 50 T 10 alpha_word 0.2 alpha_ent 0.40: \n53.1619\n\n\nK 50 T 10 alpha_word 0.3 alpha_ent 0.40: \n53.0428\n\n\nK 50 T 10 alpha_word 0.4 alpha_ent 0.40: \n54.785000000000004\n\n\nK 50 T 10 alpha_word 0.5 alpha_ent 0.40: \n54.262299999999996\n\n\nK 100 T 10 alpha_word 0.2 alpha_ent 0.30: \n50.08730000000001\n\n\nK 100 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.9088\n\n\nK 100 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.4439\n\n\nK 100 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 100 T 10 alpha_word 0.2 alpha_ent 0.40: \n54.5072\n\n\nK 100 T 10 alpha_word 0.3 alpha_ent 0.40: \n54.205400000000004\n\n\nK 100 T 10 alpha_word 0.4 alpha_ent 0.40: \n53.68989999999999\n\n\nK 100 T 10 alpha_word 0.5 alpha_ent 0.40: \n58.1959\n\n\nK 200 T 10 alpha_word 0.2 alpha_ent 0.30: \n49.0811\n\n\nK 200 T 10 alpha_word 0.3 alpha_ent 0.30: \n52.394\n\n\nK 200 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.32730000000001\n\n\nK 200 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 200 T 10 alpha_word 0.2 alpha_ent 0.40: \n49.336400000000005\n\n\nK 200 T 10 alpha_word 0.3 alpha_ent 0.40: \n50.76539999999999\n\n\nK 200 T 10 alpha_word 0.4 alpha_ent 0.40: \n51.893299999999996\n\n\nK 200 T 10 alpha_word 0.5 alpha_ent 0.40: \n55.50099999999999\n\n\n',
#              'results_deezer_6.txt': 'K 20 T 10 alpha_word 0.2 alpha_ent 0.30: \n51.4062\n\n\nK 20 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.4062\n\n\nK 20 T 10 alpha_word 0.4 alpha_ent 0.30: \n50.824000000000005\n\n\nK 20 T 10 alpha_word 0.5 alpha_ent 0.30: \n50.1422\n\n\nK 20 T 10 alpha_word 0.2 alpha_ent 0.40: \n57.5044\n\n\nK 20 T 10 alpha_word 0.3 alpha_ent 0.40: \n57.5044\n\n\nK 20 T 10 alpha_word 0.4 alpha_ent 0.40: \n57.276\n\n\nK 20 T 10 alpha_word 0.5 alpha_ent 0.40: \n56.85650000000001\n\n\nK 50 T 10 alpha_word 0.2 alpha_ent 0.30: \n51.9509\n\n\nK 50 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.5633\n\n\nK 50 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.477300000000014\n\n\nK 50 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 50 T 10 alpha_word 0.2 alpha_ent 0.40: \n57.9454\n\n\nK 50 T 10 alpha_word 0.3 alpha_ent 0.40: \n57.826299999999996\n\n\nK 50 T 10 alpha_word 0.4 alpha_ent 0.40: \n56.37950000000001\n\n\nK 50 T 10 alpha_word 0.5 alpha_ent 0.40: \n59.045800000000014\n\n\nK 100 T 10 alpha_word 0.2 alpha_ent 0.30: \n50.08730000000001\n\n\nK 100 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.9088\n\n\nK 100 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.4439\n\n\nK 100 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 100 T 10 alpha_word 0.2 alpha_ent 0.40: \n56.385700000000014\n\n\nK 100 T 10 alpha_word 0.3 alpha_ent 0.40: \n55.33249999999998\n\n\nK 100 T 10 alpha_word 0.4 alpha_ent 0.40: \n54.44129999999999\n\n\nK 100 T 10 alpha_word 0.5 alpha_ent 0.40: \n59.32299999999999\n\n\nK 200 T 10 alpha_word 0.2 alpha_ent 0.30: \n49.0811\n\n\nK 200 T 10 alpha_word 0.3 alpha_ent 0.30: \n52.394\n\n\nK 200 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.32730000000001\n\n\nK 200 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 200 T 10 alpha_word 0.2 alpha_ent 0.40: \n55.76840000000001\n\n\nK 200 T 10 alpha_word 0.3 alpha_ent 0.40: \n54.6246\n\n\nK 200 T 10 alpha_word 0.4 alpha_ent 0.40: \n54.4661\n\n\nK 200 T 10 alpha_word 0.5 alpha_ent 0.40: \n59.3602\n\n\n',
#              'results_deezer_7.txt': 'K 20 T 10 alpha_word 0.2 alpha_ent 0.30: \n51.4062\n\n\nK 20 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.4062\n\n\nK 20 T 10 alpha_word 0.4 alpha_ent 0.30: \n50.824000000000005\n\n\nK 20 T 10 alpha_word 0.5 alpha_ent 0.30: \n50.1422\n\n\nK 20 T 10 alpha_word 0.2 alpha_ent 0.40: \n54.593599999999995\n\n\nK 20 T 10 alpha_word 0.3 alpha_ent 0.40: \n54.593599999999995\n\n\nK 20 T 10 alpha_word 0.4 alpha_ent 0.40: \n54.3652\n\n\nK 20 T 10 alpha_word 0.5 alpha_ent 0.40: \n53.945699999999995\n\n\nK 50 T 10 alpha_word 0.2 alpha_ent 0.30: \n51.9509\n\n\nK 50 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.5633\n\n\nK 50 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.477300000000014\n\n\nK 50 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 50 T 10 alpha_word 0.2 alpha_ent 0.40: \n54.0007\n\n\nK 50 T 10 alpha_word 0.3 alpha_ent 0.40: \n53.8816\n\n\nK 50 T 10 alpha_word 0.4 alpha_ent 0.40: \n55.064600000000006\n\n\nK 50 T 10 alpha_word 0.5 alpha_ent 0.40: \n55.10109999999999\n\n\nK 100 T 10 alpha_word 0.2 alpha_ent 0.30: \n50.1803\n\n\nK 100 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.9088\n\n\nK 100 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.4439\n\n\nK 100 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 100 T 10 alpha_word 0.2 alpha_ent 0.40: \n49.191199999999995\n\n\nK 100 T 10 alpha_word 0.3 alpha_ent 0.40: \n51.01579999999999\n\n\nK 100 T 10 alpha_word 0.4 alpha_ent 0.40: \n51.5635\n\n\nK 100 T 10 alpha_word 0.5 alpha_ent 0.40: \n55.006299999999996\n\n\nK 200 T 10 alpha_word 0.2 alpha_ent 0.30: \n49.0811\n\n\nK 200 T 10 alpha_word 0.3 alpha_ent 0.30: \n52.394\n\n\nK 200 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.32730000000001\n\n\nK 200 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 200 T 10 alpha_word 0.2 alpha_ent 0.40: \n48.586400000000005\n\n\nK 200 T 10 alpha_word 0.3 alpha_ent 0.40: \n50.3154\n\n\nK 200 T 10 alpha_word 0.4 alpha_ent 0.40: \n51.5933\n\n\nK 200 T 10 alpha_word 0.5 alpha_ent 0.40: \n55.051\n\n\n',
#              'results_deezer_8.txt': 'K 20 T 10 alpha_word 0.2 alpha_ent 0.30: \n51.4062\n\n\nK 20 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.4062\n\n\nK 20 T 10 alpha_word 0.4 alpha_ent 0.30: \n50.824000000000005\n\n\nK 20 T 10 alpha_word 0.5 alpha_ent 0.30: \n50.1422\n\n\nK 20 T 10 alpha_word 0.2 alpha_ent 0.40: \n56.2688\n\n\nK 20 T 10 alpha_word 0.3 alpha_ent 0.40: \n56.2688\n\n\nK 20 T 10 alpha_word 0.4 alpha_ent 0.40: \n56.04039999999999\n\n\nK 20 T 10 alpha_word 0.5 alpha_ent 0.40: \n55.620900000000006\n\n\nK 50 T 10 alpha_word 0.2 alpha_ent 0.30: \n51.9509\n\n\nK 50 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.5633\n\n\nK 50 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.477300000000014\n\n\nK 50 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 50 T 10 alpha_word 0.2 alpha_ent 0.40: \n54.89680000000001\n\n\nK 50 T 10 alpha_word 0.3 alpha_ent 0.40: \n54.77770000000001\n\n\nK 50 T 10 alpha_word 0.4 alpha_ent 0.40: \n55.363299999999995\n\n\nK 50 T 10 alpha_word 0.5 alpha_ent 0.40: \n55.99719999999999\n\n\nK 100 T 10 alpha_word 0.2 alpha_ent 0.30: \n50.08730000000001\n\n\nK 100 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.9088\n\n\nK 100 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.4439\n\n\nK 100 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 100 T 10 alpha_word 0.2 alpha_ent 0.40: \n50.093700000000005\n\n\nK 100 T 10 alpha_word 0.3 alpha_ent 0.40: \n51.557300000000005\n\n\nK 100 T 10 alpha_word 0.4 alpha_ent 0.40: \n51.924499999999995\n\n\nK 100 T 10 alpha_word 0.5 alpha_ent 0.40: \n55.54780000000002\n\n\nK 200 T 10 alpha_word 0.2 alpha_ent 0.30: \n49.0811\n\n\nK 200 T 10 alpha_word 0.3 alpha_ent 0.30: \n52.394\n\n\nK 200 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.32730000000001\n\n\nK 200 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 200 T 10 alpha_word 0.2 alpha_ent 0.40: \n53.39190000000001\n\n\nK 200 T 10 alpha_word 0.3 alpha_ent 0.40: \n53.1987\n\n\nK 200 T 10 alpha_word 0.4 alpha_ent 0.40: \n53.515499999999996\n\n\nK 200 T 10 alpha_word 0.5 alpha_ent 0.40: \n57.93429999999999\n\n\n',
#              'results_deezer_9.txt': 'K 20 T 10 alpha_word 0.2 alpha_ent 0.30: \n51.4062\n\n\nK 20 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.4062\n\n\nK 20 T 10 alpha_word 0.4 alpha_ent 0.30: \n50.824000000000005\n\n\nK 20 T 10 alpha_word 0.5 alpha_ent 0.30: \n50.1422\n\n\nK 20 T 10 alpha_word 0.2 alpha_ent 0.40: \n54.5174\n\n\nK 20 T 10 alpha_word 0.3 alpha_ent 0.40: \n54.5174\n\n\nK 20 T 10 alpha_word 0.4 alpha_ent 0.40: \n54.28900000000001\n\n\nK 20 T 10 alpha_word 0.5 alpha_ent 0.40: \n53.8695\n\n\nK 50 T 10 alpha_word 0.2 alpha_ent 0.30: \n51.9509\n\n\nK 50 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.5633\n\n\nK 50 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.477300000000014\n\n\nK 50 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 50 T 10 alpha_word 0.2 alpha_ent 0.40: \n57.092200000000005\n\n\nK 50 T 10 alpha_word 0.3 alpha_ent 0.40: \n56.9731\n\n\nK 50 T 10 alpha_word 0.4 alpha_ent 0.40: \n56.095099999999995\n\n\nK 50 T 10 alpha_word 0.5 alpha_ent 0.40: \n58.19259999999999\n\n\nK 100 T 10 alpha_word 0.2 alpha_ent 0.30: \n50.129900000000006\n\n\nK 100 T 10 alpha_word 0.3 alpha_ent 0.30: \n51.9088\n\n\nK 100 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.4439\n\n\nK 100 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 100 T 10 alpha_word 0.2 alpha_ent 0.40: \n49.21170000000001\n\n\nK 100 T 10 alpha_word 0.3 alpha_ent 0.40: \n51.02810000000001\n\n\nK 100 T 10 alpha_word 0.4 alpha_ent 0.40: \n51.5717\n\n\nK 100 T 10 alpha_word 0.5 alpha_ent 0.40: \n55.018600000000006\n\n\nK 200 T 10 alpha_word 0.2 alpha_ent 0.30: \n49.0811\n\n\nK 200 T 10 alpha_word 0.3 alpha_ent 0.30: \n52.394\n\n\nK 200 T 10 alpha_word 0.4 alpha_ent 0.30: \n51.32730000000001\n\n\nK 200 T 10 alpha_word 0.5 alpha_ent 0.30: \n48.678399999999996\n\n\nK 200 T 10 alpha_word 0.2 alpha_ent 0.40: \n51.6479\n\n\nK 200 T 10 alpha_word 0.3 alpha_ent 0.40: \n52.1523\n\n\nK 200 T 10 alpha_word 0.4 alpha_ent 0.40: \n52.817899999999995\n\n\nK 200 T 10 alpha_word 0.5 alpha_ent 0.40: \n56.887900000000016\n\n\n'})

# %%
def preprocess_data(data_dict):
    # Regular expression pattern to extract data
    pattern = r'K (\d+) T (\d+) alpha_word (\d\.\d) alpha_ent (\d\.\d+): \n(\d+\.\d+)'

    # Dictionary to store the processed data
    processed_data = defaultdict(list)

    # Looping through each file's data in the dictionary
    for file_name, file_data in data_dict.items():
        # Finding all matches of the pattern in the current file's data
        matches = re.findall(pattern, file_data)

        # Adding the extracted data to the processed_data dictionary
        for match in matches:
            K, T, alpha_word, alpha_ent, value = match
            processed_data[file_name].append({
                'K': int(K),
                'T': int(T),
                'alpha_word': float(alpha_word),
                'alpha_ent': float(alpha_ent),
                'value': float(value)
            })

    return processed_data

processed = preprocess_data(data)

# %%
processed
# Out:
# defaultdict(list,
#             {'results_deezer_0.txt': [{'K': 20,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 51.4062},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.4062},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 50.824000000000005},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 50.1422},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 59.6488},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 59.6488},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 59.42040000000001},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 59.0009},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 51.9509},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.5633},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.477300000000014},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 57.787600000000005},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 57.6685},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 56.3269},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 58.888},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 50.08730000000001},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.9088},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.4439},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 52.974700000000006},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 53.2859},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 53.0769},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 57.2764},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 49.0811},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 52.394},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.32730000000001},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 55.3034},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 54.34559999999999},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 54.2801},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 59.0812}],
#              'results_deezer_1.txt': [{'K': 20,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 51.4062},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.4062},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 50.824000000000005},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 50.1422},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 54.8392},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 54.8392},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 54.610800000000005},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 54.19130000000001},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 51.9509},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.5633},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.477300000000014},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 57.258700000000005},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 57.1396},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 56.1506},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 58.3591},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 50.08730000000001},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.9088},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.4439},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 51.6697},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 52.5029},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 52.5549},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 56.49339999999998},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 49.0811},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 52.394},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.32730000000001},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 53.36890000000001},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 53.1849},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 53.506299999999996},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 57.9205},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 51.4062},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.4062},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 50.824000000000005},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 50.1422},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 54.5056},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 54.5056},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 54.2772},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 53.85770000000001},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 51.9509},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.5633},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.477300000000014},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 52.856800000000014},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 52.73770000000001},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 54.6833},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 53.95720000000001},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 50.08730000000001},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.9088},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.4439},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 45.0547},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 48.5339},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 49.908899999999996},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 52.52440000000001},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 49.0811},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 52.394},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.32730000000001},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 49.83040000000001},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 51.061800000000005},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 52.0909},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 55.797399999999996}],
#              'results_deezer_10.txt': [{'K': 20,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 51.4062},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.4062},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 50.824000000000005},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 50.1422},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 54.211999999999996},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 54.211999999999996},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 53.983599999999996},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 53.5641},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 51.9509},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.5633},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.477300000000014},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 58.00090000000001},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 57.881800000000005},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 56.398},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 59.10129999999999},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 49.95269999999999},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.9088},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.4439},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 54.3262},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 54.09680000000001},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 53.61749999999999},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 58.087300000000006},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 49.0811},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 52.394},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.32730000000001},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 48.77140000000001},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 50.4264},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 51.667300000000004},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 55.16200000000001}],
#              'results_deezer_2.txt': [{'K': 20,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 51.4062},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.4062},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 50.824000000000005},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 50.1422},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 57.147800000000004},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 57.147800000000004},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 56.91940000000001},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 56.499900000000004},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 51.9509},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.5633},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.477300000000014},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 52.607200000000006},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 52.4881},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 54.600100000000005},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 53.707599999999985},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 50.112800000000014},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.9088},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.4439},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 53.15019999999999},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 53.3912},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 53.1471},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 57.38169999999999},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 49.0811},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 52.394},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.32730000000001},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 46.7294},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 49.20120000000001},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 50.8505},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 53.9368}],
#              'results_deezer_3.txt': [{'K': 20,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 51.4062},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.4062},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 50.824000000000005},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 50.1422},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 55.91359999999999},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 55.91359999999999},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 55.68519999999999},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 55.265699999999995},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 51.9509},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.5633},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.477300000000014},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 54.8254},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 54.706300000000006},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 55.339499999999994},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 55.9258},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 50.20020000000001},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.9088},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.4439},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 54.46769999999999},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 54.181699999999985},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 53.67409999999999},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 58.17219999999998},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 49.0811},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 52.394},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.32730000000001},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 46.3959},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 49.001099999999994},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 50.717099999999995},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 53.73669999999999}],
#              'results_deezer_4.txt': [{'K': 20,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 51.4062},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.4062},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 50.824000000000005},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 50.1422},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 54.46379999999999},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 54.46379999999999},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 54.23540000000001},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 53.815900000000006},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 51.9509},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.5633},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.477300000000014},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 57.04900000000001},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 56.9299},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 56.08069999999999},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 58.14939999999999},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 50.1803},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.9088},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.4439},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 50.636199999999995},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 51.882799999999996},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 52.14149999999999},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 55.87329999999999},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 49.0811},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 52.394},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.32730000000001},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 46.8879},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 49.296299999999995},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 50.9139},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 54.0319}],
#              'results_deezer_5.txt': [{'K': 20,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 51.4062},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.4062},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 50.824000000000005},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 50.1422},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 57.48019999999999},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 57.48019999999999},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 57.251799999999996},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 56.832300000000004},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 51.9509},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.5633},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.477300000000014},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 53.1619},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 53.0428},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 54.785000000000004},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 54.262299999999996},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 50.08730000000001},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.9088},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.4439},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 54.5072},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 54.205400000000004},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 53.68989999999999},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 58.1959},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 49.0811},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 52.394},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.32730000000001},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 49.336400000000005},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 50.76539999999999},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 51.893299999999996},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 55.50099999999999}],
#              'results_deezer_6.txt': [{'K': 20,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 51.4062},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.4062},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 50.824000000000005},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 50.1422},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 57.5044},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 57.5044},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 57.276},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 56.85650000000001},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 51.9509},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.5633},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.477300000000014},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 57.9454},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 57.826299999999996},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 56.37950000000001},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 59.045800000000014},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 50.08730000000001},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.9088},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.4439},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 56.385700000000014},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 55.33249999999998},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 54.44129999999999},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 59.32299999999999},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 49.0811},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 52.394},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.32730000000001},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 55.76840000000001},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 54.6246},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 54.4661},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 59.3602}],
#              'results_deezer_7.txt': [{'K': 20,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 51.4062},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.4062},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 50.824000000000005},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 50.1422},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 54.593599999999995},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 54.593599999999995},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 54.3652},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 53.945699999999995},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 51.9509},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.5633},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.477300000000014},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 54.0007},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 53.8816},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 55.064600000000006},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 55.10109999999999},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 50.1803},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.9088},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.4439},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 49.191199999999995},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 51.01579999999999},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 51.5635},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 55.006299999999996},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 49.0811},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 52.394},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.32730000000001},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 48.586400000000005},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 50.3154},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 51.5933},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 55.051}],
#              'results_deezer_8.txt': [{'K': 20,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 51.4062},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.4062},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 50.824000000000005},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 50.1422},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 56.2688},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 56.2688},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 56.04039999999999},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 55.620900000000006},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 51.9509},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.5633},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.477300000000014},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 54.89680000000001},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 54.77770000000001},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 55.363299999999995},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 55.99719999999999},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 50.08730000000001},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.9088},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.4439},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 50.093700000000005},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 51.557300000000005},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 51.924499999999995},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 55.54780000000002},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 49.0811},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 52.394},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.32730000000001},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 53.39190000000001},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 53.1987},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 53.515499999999996},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 57.93429999999999}],
#              'results_deezer_9.txt': [{'K': 20,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 51.4062},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.4062},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 50.824000000000005},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 50.1422},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 54.5174},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 54.5174},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 54.28900000000001},
#               {'K': 20,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 53.8695},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 51.9509},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.5633},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.477300000000014},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 57.092200000000005},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 56.9731},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 56.095099999999995},
#               {'K': 50,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 58.19259999999999},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 50.129900000000006},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 51.9088},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.4439},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 49.21170000000001},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 51.02810000000001},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 51.5717},
#               {'K': 100,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 55.018600000000006},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.3,
#                'value': 49.0811},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.3,
#                'value': 52.394},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.3,
#                'value': 51.32730000000001},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.3,
#                'value': 48.678399999999996},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.2,
#                'alpha_ent': 0.4,
#                'value': 51.6479},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.3,
#                'alpha_ent': 0.4,
#                'value': 52.1523},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.4,
#                'alpha_ent': 0.4,
#                'value': 52.817899999999995},
#               {'K': 200,
#                'T': 10,
#                'alpha_word': 0.5,
#                'alpha_ent': 0.4,
#                'value': 56.887900000000016}]})

# %%
# Now calculate mean, emdian, standard deviation, variance and range for the value for each setting of K, T, alpha_word and alpha_ent
from statistics import mean, median, stdev, variance

def calculate_statistics(processed_data):
    # Dictionary to store the calculated statistics
    statistics = defaultdict(dict)

    # Looping through each file's data in the dictionary
    for file_name, file_data in processed_data.items():
        # Looping through each setting in the file's data
        for setting in file_data:
            K = setting['K']
            T = setting['T']
            alpha_word = setting['alpha_word']
            alpha_ent = setting['alpha_ent']
            value = setting['value']

            # If the setting is not in the dictionary, add it
            if (K, T, alpha_word, alpha_ent) not in statistics:
                statistics[(K, T, alpha_word, alpha_ent)] = []

            # Add the value to the list of values for the setting
            statistics[(K, T, alpha_word, alpha_ent)].append(value)

    # Looping through each setting in the dictionary
    for setting, values in statistics.items():
        # Calculate the statistics for the values
        statistics[setting] = {
            'mean': mean(values),
            'median': median(values),
            'stdev': stdev(values),
            'variance': variance(values),
            'range': max(values) - min(values)
        }

    return statistics

statistics = calculate_statistics(processed)
statistics
# Out:
# defaultdict(dict,
#             {(20, 10, 0.2, 0.3): {'mean': 51.4062,
#               'median': 51.4062,
#               'stdev': 0.0,
#               'variance': 0.0,
#               'range': 0.0},
#              (20, 10, 0.3, 0.3): {'mean': 51.4062,
#               'median': 51.4062,
#               'stdev': 0.0,
#               'variance': 0.0,
#               'range': 0.0},
#              (20, 10, 0.4, 0.3): {'mean': 50.824000000000005,
#               'median': 50.824000000000005,
#               'stdev': 0.0,
#               'variance': 0.0,
#               'range': 0.0},
#              (20, 10, 0.5, 0.3): {'mean': 50.1422,
#               'median': 50.1422,
#               'stdev': 0.0,
#               'variance': 0.0,
#               'range': 0.0},
#              (20, 10, 0.2, 0.4): {'mean': 55.9246,
#               'median': 55.37639999999999,
#               'stdev': 1.7165107398440598,
#               'variance': 2.946409120000002,
#               'range': 5.436800000000005},
#              (20, 10, 0.3, 0.4): {'mean': 55.9246,
#               'median': 55.37639999999999,
#               'stdev': 1.7165107398440598,
#               'variance': 2.946409120000002,
#               'range': 5.436800000000005},
#              (20, 10, 0.4, 0.4): {'mean': 55.696200000000005,
#               'median': 55.147999999999996,
#               'stdev': 1.7165107398440598,
#               'variance': 2.946409120000001,
#               'range': 5.436800000000012},
#              (20, 10, 0.5, 0.4): {'mean': 55.276700000000005,
#               'median': 54.728500000000004,
#               'stdev': 1.7165107398440593,
#               'variance': 2.9464091199999998,
#               'range': 5.436799999999998},
#              (50, 10, 0.2, 0.3): {'mean': 51.9509,
#               'median': 51.9509,
#               'stdev': 0.0,
#               'variance': 0.0,
#               'range': 0.0},
#              (50, 10, 0.3, 0.3): {'mean': 51.5633,
#               'median': 51.5633,
#               'stdev': 0.0,
#               'variance': 0.0,
#               'range': 0.0},
#              (50, 10, 0.4, 0.3): {'mean': 51.477300000000014,
#               'median': 51.477300000000014,
#               'stdev': 0.0,
#               'variance': 0.0,
#               'range': 0.0},
#              (50, 10, 0.5, 0.3): {'mean': 48.678399999999996,
#               'median': 48.678399999999996,
#               'stdev': 0.0,
#               'variance': 0.0,
#               'range': 0.0},
#              (50, 10, 0.2, 0.4): {'mean': 55.62355000000001,
#               'median': 55.97290000000001,
#               'stdev': 2.1148886411689505,
#               'variance': 4.472753964545451,
#               'range': 5.393700000000003},
#              (50, 10, 0.3, 0.4): {'mean': 55.504450000000006,
#               'median': 55.85380000000001,
#               'stdev': 2.1148886411689505,
#               'variance': 4.472753964545449,
#               'range': 5.393700000000003},
#              (50, 10, 0.4, 0.4): {'mean': 55.60555,
#               'median': 55.721999999999994,
#               'stdev': 0.7049628803896495,
#               'variance': 0.49697266272727125,
#               'range': 1.7978999999999985},
#              (50, 10, 0.5, 0.4): {'mean': 56.723949999999995,
#               'median': 57.07329999999999,
#               'stdev': 2.1148886411689527,
#               'variance': 4.47275396454546,
#               'range': 5.393700000000003},
#              (100, 10, 0.2, 0.3): {'mean': 50.106666666666676,
#               'median': 50.08730000000001,
#               'stdev': 0.06475532036174096,
#               'variance': 0.004193251515151704,
#               'range': 0.24750000000001648},
#              (100, 10, 0.3, 0.3): {'mean': 51.9088,
#               'median': 51.9088,
#               'stdev': 0.0,
#               'variance': 0.0,
#               'range': 0.0},
#              (100, 10, 0.4, 0.3): {'mean': 51.4439,
#               'median': 51.4439,
#               'stdev': 0.0,
#               'variance': 0.0,
#               'range': 0.0},
#              (100, 10, 0.5, 0.3): {'mean': 48.678399999999996,
#               'median': 48.678399999999996,
#               'stdev': 0.0,
#               'variance': 0.0,
#               'range': 0.0},
#              (100, 10, 0.2, 0.4): {'mean': 51.80574166666666,
#               'median': 52.3222,
#               'stdev': 3.1384061564194523,
#               'variance': 9.849593202651521,
#               'range': 11.331000000000017},
#              (100, 10, 0.3, 0.4): {'mean': 52.584525,
#               'median': 52.8944,
#               'stdev': 1.8830436938516675,
#               'variance': 3.5458535529545325,
#               'range': 6.798599999999979},
#              (100, 10, 0.4, 0.4): {'mean': 52.609316666666665,
#               'median': 52.8159,
#               'stdev': 1.2553624625677786,
#               'variance': 1.5759349124242374,
#               'range': 4.5323999999999955},
#              (100, 10, 0.5, 0.4): {'mean': 56.575025,
#               'median': 56.88489999999999,
#               'stdev': 1.8830436938516668,
#               'variance': 3.54585355295453,
#               'range': 6.798599999999986},
#              (200, 10, 0.2, 0.3): {'mean': 49.0811,
#               'median': 49.0811,
#               'stdev': 0.0,
#               'variance': 0.0,
#               'range': 0.0},
#              (200, 10, 0.3, 0.3): {'mean': 52.394,
#               'median': 52.394,
#               'stdev': 0.0,
#               'variance': 0.0,
#               'range': 0.0},
#              (200, 10, 0.4, 0.3): {'mean': 51.32730000000001,
#               'median': 51.32730000000001,
#               'stdev': 0.0,
#               'variance': 0.0,
#               'range': 0.0},
#              (200, 10, 0.5, 0.3): {'mean': 48.678399999999996,
#               'median': 48.678399999999996,
#               'stdev': 0.0,
#               'variance': 0.0,
#               'range': 0.0},
#              (200, 10, 0.2, 0.4): {'mean': 50.501525,
#               'median': 49.58340000000001,
#               'stdev': 3.3207418265214637,
#               'variance': 11.027326278409106,
#               'range': 9.37250000000001},
#              (200, 10, 0.3, 0.4): {'mean': 51.464475,
#               'median': 50.9136,
#               'stdev': 1.9924450959128763,
#               'variance': 3.969837460227271,
#               'range': 5.623500000000007},
#              (200, 10, 0.4, 0.4): {'mean': 52.35935,
#               'median': 51.99209999999999,
#               'stdev': 1.328296730608584,
#               'variance': 1.7643722045454533,
#               'range': 3.7490000000000023},
#              (200, 10, 0.5, 0.4): {'mean': 56.200075,
#               'median': 55.64919999999999,
#               'stdev': 1.9924450959128774,
#               'variance': 3.9698374602272755,
#               'range': 5.623500000000007}})

# %%
# alright now create a table of these sttatistics
import pandas as pd

def create_table(statistics):
    # Create a DataFrame from the statistics dictionary
    df = pd.DataFrame(statistics).T

    # Rename the columns
    df.columns = ['mean', 'median', 'stdev', 'variance', 'range']

    return df

table = create_table(statistics)
table
# Out:
#                      mean   median     stdev   variance    range
# 20  10 0.2 0.3  51.406200  51.4062  0.000000   0.000000   0.0000
#        0.3 0.3  51.406200  51.4062  0.000000   0.000000   0.0000
#        0.4 0.3  50.824000  50.8240  0.000000   0.000000   0.0000
#        0.5 0.3  50.142200  50.1422  0.000000   0.000000   0.0000
#        0.2 0.4  55.924600  55.3764  1.716511   2.946409   5.4368
#        0.3 0.4  55.924600  55.3764  1.716511   2.946409   5.4368
#        0.4 0.4  55.696200  55.1480  1.716511   2.946409   5.4368
#        0.5 0.4  55.276700  54.7285  1.716511   2.946409   5.4368
# 50  10 0.2 0.3  51.950900  51.9509  0.000000   0.000000   0.0000
#        0.3 0.3  51.563300  51.5633  0.000000   0.000000   0.0000
#        0.4 0.3  51.477300  51.4773  0.000000   0.000000   0.0000
#        0.5 0.3  48.678400  48.6784  0.000000   0.000000   0.0000
#        0.2 0.4  55.623550  55.9729  2.114889   4.472754   5.3937
#        0.3 0.4  55.504450  55.8538  2.114889   4.472754   5.3937
#        0.4 0.4  55.605550  55.7220  0.704963   0.496973   1.7979
#        0.5 0.4  56.723950  57.0733  2.114889   4.472754   5.3937
# 100 10 0.2 0.3  50.106667  50.0873  0.064755   0.004193   0.2475
#        0.3 0.3  51.908800  51.9088  0.000000   0.000000   0.0000
#        0.4 0.3  51.443900  51.4439  0.000000   0.000000   0.0000
#        0.5 0.3  48.678400  48.6784  0.000000   0.000000   0.0000
#        0.2 0.4  51.805742  52.3222  3.138406   9.849593  11.3310
#        0.3 0.4  52.584525  52.8944  1.883044   3.545854   6.7986
#        0.4 0.4  52.609317  52.8159  1.255362   1.575935   4.5324
#        0.5 0.4  56.575025  56.8849  1.883044   3.545854   6.7986
# 200 10 0.2 0.3  49.081100  49.0811  0.000000   0.000000   0.0000
#        0.3 0.3  52.394000  52.3940  0.000000   0.000000   0.0000
#        0.4 0.3  51.327300  51.3273  0.000000   0.000000   0.0000
#        0.5 0.3  48.678400  48.6784  0.000000   0.000000   0.0000
#        0.2 0.4  50.501525  49.5834  3.320742  11.027326   9.3725
#        0.3 0.4  51.464475  50.9136  1.992445   3.969837   5.6235
#        0.4 0.4  52.359350  51.9921  1.328297   1.764372   3.7490
#        0.5 0.4  56.200075  55.6492  1.992445   3.969837   5.6235

# %%
# sort table by the values in the index
table = table.sort_index()
table
# Out:
#                      mean   median     stdev   variance    range
# 20  10 0.2 0.3  51.406200  51.4062  0.000000   0.000000   0.0000
#            0.4  55.924600  55.3764  1.716511   2.946409   5.4368
#        0.3 0.3  51.406200  51.4062  0.000000   0.000000   0.0000
#            0.4  55.924600  55.3764  1.716511   2.946409   5.4368
#        0.4 0.3  50.824000  50.8240  0.000000   0.000000   0.0000
#            0.4  55.696200  55.1480  1.716511   2.946409   5.4368
#        0.5 0.3  50.142200  50.1422  0.000000   0.000000   0.0000
#            0.4  55.276700  54.7285  1.716511   2.946409   5.4368
# 50  10 0.2 0.3  51.950900  51.9509  0.000000   0.000000   0.0000
#            0.4  55.623550  55.9729  2.114889   4.472754   5.3937
#        0.3 0.3  51.563300  51.5633  0.000000   0.000000   0.0000
#            0.4  55.504450  55.8538  2.114889   4.472754   5.3937
#        0.4 0.3  51.477300  51.4773  0.000000   0.000000   0.0000
#            0.4  55.605550  55.7220  0.704963   0.496973   1.7979
#        0.5 0.3  48.678400  48.6784  0.000000   0.000000   0.0000
#            0.4  56.723950  57.0733  2.114889   4.472754   5.3937
# 100 10 0.2 0.3  50.106667  50.0873  0.064755   0.004193   0.2475
#            0.4  51.805742  52.3222  3.138406   9.849593  11.3310
#        0.3 0.3  51.908800  51.9088  0.000000   0.000000   0.0000
#            0.4  52.584525  52.8944  1.883044   3.545854   6.7986
#        0.4 0.3  51.443900  51.4439  0.000000   0.000000   0.0000
#            0.4  52.609317  52.8159  1.255362   1.575935   4.5324
#        0.5 0.3  48.678400  48.6784  0.000000   0.000000   0.0000
#            0.4  56.575025  56.8849  1.883044   3.545854   6.7986
# 200 10 0.2 0.3  49.081100  49.0811  0.000000   0.000000   0.0000
#            0.4  50.501525  49.5834  3.320742  11.027326   9.3725
#        0.3 0.3  52.394000  52.3940  0.000000   0.000000   0.0000
#            0.4  51.464475  50.9136  1.992445   3.969837   5.6235
#        0.4 0.3  51.327300  51.3273  0.000000   0.000000   0.0000
#            0.4  52.359350  51.9921  1.328297   1.764372   3.7490
#        0.5 0.3  48.678400  48.6784  0.000000   0.000000   0.0000
#            0.4  56.200075  55.6492  1.992445   3.969837   5.6235

# %%
# also apply cv to the value for each setting of K, T, alpha_word and alpha_ent
def calculate_cv(processed_data):
    # Dictionary to store the calculated CVs
    cvs = defaultdict(dict)

    # Looping through each file's data in the dictionary
    for file_name, file_data in processed_data.items():
        # Looping through each setting in the file's data
        for setting in file_data:
            K = setting['K']
            T = setting['T']
            alpha_word = setting['alpha_word']
            alpha_ent = setting['alpha_ent']
            value = setting['value']

            # If the setting is not in the dictionary, add it
            if (K, T, alpha_word, alpha_ent) not in cvs:
                cvs[(K, T, alpha_word, alpha_ent)] = []

            # Add the value to the list of values for the setting
            values = cvs[(K, T, alpha_word, alpha_ent)]
            values.append(value)

            # If there are at least two values, calculate the CV
            if len(values) >= 2:
                values.append(stdev(values) / mean(values))

    # Looping through each setting in the dictionary
    for setting, values in cvs.items():
        # Calculate the CV for the values
        cvs[setting] = mean(values)

    return cvs

cvs = calculate_cv(processed)
cvs
# Out:
# defaultdict(dict,
#             {(20, 10, 0.2, 0.3): 27.187532200001243,
#              (20, 10, 0.3, 0.3): 27.187532200001243,
#              (20, 10, 0.4, 0.3): 26.883694931958544,
#              (20, 10, 0.5, 0.3): 26.527876308193857,
#              (20, 10, 0.2, 0.4): 29.548509904886895,
#              (20, 10, 0.3, 0.4): 29.548509904886895,
#              (20, 10, 0.4, 0.4): 29.429331599452095,
#              (20, 10, 0.5, 0.4): 29.21043775598385,
#              (50, 10, 0.2, 0.3): 27.471797450236917,
#              (50, 10, 0.3, 0.3): 27.26951890099313,
#              (50, 10, 0.4, 0.3): 27.224637591030945,
#              (50, 10, 0.5, 0.3): 25.763937626658947,
#              (50, 10, 0.2, 0.4): 29.389405351076526,
#              (50, 10, 0.3, 0.4): 29.327255739972923,
#              (50, 10, 0.4, 0.4): 29.37920144025429,
#              (50, 10, 0.5, 0.4): 29.963622178511176,
#              (100, 10, 0.2, 0.3): 26.509331327456646,
#              (100, 10, 0.3, 0.3): 27.449826571561204,
#              (100, 10, 0.4, 0.3): 27.207206932412415,
#              (100, 10, 0.5, 0.3): 25.763937626658947,
#              (100, 10, 0.2, 0.4): 27.398563241609992,
#              (100, 10, 0.3, 0.4): 27.803528057760687,
#              (100, 10, 0.4, 0.4): 27.815974624608675,
#              (100, 10, 0.5, 0.4): 29.885901987998327,
#              (200, 10, 0.2, 0.3): 25.9741029142712,
#              (200, 10, 0.3, 0.3): 27.703039104925274,
#              (200, 10, 0.4, 0.3): 27.146356144538103,
#              (200, 10, 0.5, 0.3): 25.763937626658947,
#              (200, 10, 0.2, 0.4): 26.71811564501002,
#              (200, 10, 0.3, 0.4): 27.219142368662602,
#              (200, 10, 0.4, 0.4): 27.685612179274816,
#              (200, 10, 0.5, 0.4): 29.69034528345463})

# %%
# make cv table
def create_cv_table(cvs):
    # Create a DataFrame from the CVs dictionary
    df = pd.DataFrame(cvs, index=['cv']).T

    return df

cv_table = create_cv_table(cvs)
cv_table
# Out:
#                        cv
# 20  10 0.2 0.3  27.187532
#        0.3 0.3  27.187532
#        0.4 0.3  26.883695
#        0.5 0.3  26.527876
#        0.2 0.4  29.548510
#        0.3 0.4  29.548510
#        0.4 0.4  29.429332
#        0.5 0.4  29.210438
# 50  10 0.2 0.3  27.471797
#        0.3 0.3  27.269519
#        0.4 0.3  27.224638
#        0.5 0.3  25.763938
#        0.2 0.4  29.389405
#        0.3 0.4  29.327256
#        0.4 0.4  29.379201
#        0.5 0.4  29.963622
# 100 10 0.2 0.3  26.509331
#        0.3 0.3  27.449827
#        0.4 0.3  27.207207
#        0.5 0.3  25.763938
#        0.2 0.4  27.398563
#        0.3 0.4  27.803528
#        0.4 0.4  27.815975
#        0.5 0.4  29.885902
# 200 10 0.2 0.3  25.974103
#        0.3 0.3  27.703039
#        0.4 0.3  27.146356
#        0.5 0.3  25.763938
#        0.2 0.4  26.718116
#        0.3 0.4  27.219142
#        0.4 0.4  27.685612
#        0.5 0.4  29.690345

# %%
# do the shapiro test for normality on the aggregated data
from scipy.stats import shapiro

p_values = table['mean']
shapiro(p_values)
# Out:
# ShapiroResult(statistic=0.9014052748680115, pvalue=0.0067262486554682255)

# %%
# alright now do the homogeneity of variances test of levene for the aggregated data
from scipy.stats import levene

b_values = [
    50.2, 53.1, 48.5, 53.3, 53.2, 56.4, 52.5, 56.3,
    48.9, 49.2, 52.1, 50.9, 51.5, 52.6, 56.3, 60.6, 
    51.4, 50.8, 51.5, 55.3, 52.2, 48.1, 50.8, 54.9, 
    48.4, 50.6, 49.8, 51.6, 50, 49, 55.4, 53.3
    ]

p_values = table['mean']
levene(p_values, b_values)
# Out:
# LeveneResult(statistic=0.13202522718070456, pvalue=0.7175773733918681)

# %%
# alright now let's do the paired t test for the aggregated data
from scipy.stats import ttest_rel

p_values = table['mean']

b_values = [
    50.2, 53.1, 48.5, 53.3, 53.2, 56.4, 52.5, 56.3,
    48.9, 49.2, 52.1, 50.9, 51.5, 52.6, 56.3, 60.6, 
    51.4, 50.8, 51.5, 55.3, 52.2, 48.1, 50.8, 54.9, 
    48.4, 50.6, 49.8, 51.6, 50, 49, 55.4, 53.3
    ]
ttest_rel(p_values, b_values)
# Out:
# TtestResult(statistic=0.7256256632667231, pvalue=0.47351109185532136, df=31)
